# %%
from matplotlib import pyplot;
from pylab import genfromtxt;  
mat0 = genfromtxt("temp.dat");
#mat1 = genfromtxt("data1.txt");
#X=mat0[:,0]
#Y=mat0[:,1]

pyplot.plot(mat0[:,1], mat0[:,0],label = "X vs time")
#pyplot.plot(mat0[:,2], mat0[:,3],label="theta/time")
pyplot.xlabel('time')
pyplot.ylabel('X')
pyplot.legend()
pyplot.show()
